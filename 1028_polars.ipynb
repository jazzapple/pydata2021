# %%
import polars as pl
from polars import col, lit
import numpy as np

# %%
df = pl.DataFrame(
    {
        "A": [1, 2, 3, 4, 5],
        "fruits": ["banana", "banana", "apple", "apple", "banana"],
        "B": [5, 4, 3, 2, 1],
        "cars": ["beetle", "audi", "beetle", "beetle", "beetle"],
    }
)

# %%
(df
    .sort("fruits")
    .select([
    "fruits",
    "cars",
    lit("fruits").alias("literal_string_fruits"),
    col("B").filter(col("cars") == "beetle").sum(),
    col("A").filter(col("B") > 2).sum().over("cars").alias("sum_A_by_cars"),       # groups by "cars"
    col("A").sum().over("fruits").alias("sum_A_by_fruits"),                        # groups by "fruits"
    col("A").reverse().over("fruits").flatten().alias("rev_A_by_fruits"),          # groups by "fruits
    col("A").sort_by("B").over("fruits").flatten().alias("sort_A_by_B_by_fruits"),  # groups by "fruits"
    np.exp(col("A")).alias("exponent")
    ])
)
# Out:
# shape: (5, 9)
# ┌────────┬────────┬─────────────┬─────┬─────┬─────────────┬─────────────┬─────────────┬────────────┐
# │ fruits ┆ cars   ┆ literal_str ┆ B   ┆ ... ┆ sum_A_by_fr ┆ rev_A_by_fr ┆ sort_A_by_B ┆ exponent   │
# │ ---    ┆ ---    ┆ ing_fruits  ┆ --- ┆     ┆ uits        ┆ uits        ┆ _by_fruits  ┆ ---        │
# │ str    ┆ str    ┆ ---         ┆ i64 ┆     ┆ ---         ┆ ---         ┆ ---         ┆ f64        │
# │        ┆        ┆ str         ┆     ┆     ┆ i64         ┆ i64         ┆ i64         ┆            │
# ╞════════╪════════╪═════════════╪═════╪═════╪═════════════╪═════════════╪═════════════╪════════════╡
# │ apple  ┆ beetle ┆ fruits      ┆ 11  ┆ ... ┆ 7           ┆ 4           ┆ 4           ┆ 20.0855369 │
# │        ┆        ┆             ┆     ┆     ┆             ┆             ┆             ┆ 23187668   │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ apple  ┆ beetle ┆ fruits      ┆ 11  ┆ ... ┆ 7           ┆ 3           ┆ 3           ┆ 54.5981500 │
# │        ┆        ┆             ┆     ┆     ┆             ┆             ┆             ┆ 33144236   │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ banana ┆ beetle ┆ fruits      ┆ 11  ┆ ... ┆ 8           ┆ 5           ┆ 5           ┆ 2.71828182 │
# │        ┆        ┆             ┆     ┆     ┆             ┆             ┆             ┆ 8459045    │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ banana ┆ audi   ┆ fruits      ┆ 11  ┆ ... ┆ 8           ┆ 2           ┆ 2           ┆ 7.38905609 │
# │        ┆        ┆             ┆     ┆     ┆             ┆             ┆             ┆ 893065     │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ banana ┆ beetle ┆ fruits      ┆ 11  ┆ ... ┆ 8           ┆ 1           ┆ 1           ┆ 148.413159 │
# │        ┆        ┆             ┆     ┆     ┆             ┆             ┆             ┆ 1025766    │
# └────────┴────────┴─────────────┴─────┴─────┴─────────────┴─────────────┴─────────────┴────────────┘

# %%
# if else
df.with_column(    
    pl.when(col("cars")=="audi").then(col("B")).otherwise((-1)).alias("new")
)
# Out:
# shape: (5, 5)
# ┌─────┬────────┬─────┬────────┬─────┐
# │ A   ┆ fruits ┆ B   ┆ cars   ┆ new │
# │ --- ┆ ---    ┆ --- ┆ ---    ┆ --- │
# │ i64 ┆ str    ┆ i64 ┆ str    ┆ i64 │
# ╞═════╪════════╪═════╪════════╪═════╡
# │ 1   ┆ banana ┆ 5   ┆ beetle ┆ -1  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┤
# │ 2   ┆ banana ┆ 4   ┆ audi   ┆ 4   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┤
# │ 3   ┆ apple  ┆ 3   ┆ beetle ┆ -1  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┤
# │ 4   ┆ apple  ┆ 2   ┆ beetle ┆ -1  │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┤
# │ 5   ┆ banana ┆ 1   ┆ beetle ┆ -1  │
# └─────┴────────┴─────┴────────┴─────┘

# %%
# where
df.filter(col("cars")=="beetle")
# Out:
# shape: (4, 4)
# ┌─────┬────────┬─────┬────────┐
# │ A   ┆ fruits ┆ B   ┆ cars   │
# │ --- ┆ ---    ┆ --- ┆ ---    │
# │ i64 ┆ str    ┆ i64 ┆ str    │
# ╞═════╪════════╪═════╪════════╡
# │ 1   ┆ banana ┆ 5   ┆ beetle │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 3   ┆ apple  ┆ 3   ┆ beetle │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 4   ┆ apple  ┆ 2   ┆ beetle │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ 5   ┆ banana ┆ 1   ┆ beetle │
# └─────┴────────┴─────┴────────┘

# %%
# select columns
df.select([
    pl.all().exclude("cars")
    ])
# Out:
# shape: (5, 3)
# ┌─────┬────────┬─────┐
# │ A   ┆ fruits ┆ B   │
# │ --- ┆ ---    ┆ --- │
# │ i64 ┆ str    ┆ i64 │
# ╞═════╪════════╪═════╡
# │ 1   ┆ banana ┆ 5   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┤
# │ 2   ┆ banana ┆ 4   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┤
# │ 3   ┆ apple  ┆ 3   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┤
# │ 4   ┆ apple  ┆ 2   │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┤
# │ 5   ┆ banana ┆ 1   │
# └─────┴────────┴─────┘

# %%
df.groupby("fruits").agg([
    col("cars")
])
# Out:
# shape: (2, 2)
# ┌────────┬──────────────────────────────┐
# │ fruits ┆ cars                         │
# │ ---    ┆ ---                          │
# │ str    ┆ list [str]                   │
# ╞════════╪══════════════════════════════╡
# │ apple  ┆ ["beetle", "beetle"]         │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ banana ┆ ["beetle", "audi", "beetle"] │
# └────────┴──────────────────────────────┘

# %%
df.groupby("fruits").agg([
    col("cars").count().alias("car_count")
])
# Out:
# shape: (2, 2)
# ┌────────┬───────────┐
# │ fruits ┆ car_count │
# │ ---    ┆ ---       │
# │ str    ┆ u32       │
# ╞════════╪═══════════╡
# │ banana ┆ 3         │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┤
# │ apple  ┆ 2         │
# └────────┴───────────┘

# %%
# apply
(df.select([
    "fruits",
    "cars",
    "A",
    col("A").apply(lambda x: np.exp(x)).alias("a_new")
]))
# Out:
# shape: (5, 4)
# ┌────────┬────────┬─────┬────────────────────┐
# │ fruits ┆ cars   ┆ A   ┆ a_new              │
# │ ---    ┆ ---    ┆ --- ┆ ---                │
# │ str    ┆ str    ┆ i64 ┆ f64                │
# ╞════════╪════════╪═════╪════════════════════╡
# │ banana ┆ beetle ┆ 1   ┆ 2.718281828459045  │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ banana ┆ audi   ┆ 2   ┆ 7.38905609893065   │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ apple  ┆ beetle ┆ 3   ┆ 20.085536923187668 │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ apple  ┆ beetle ┆ 4   ┆ 54.598150033144236 │
# ├╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ banana ┆ beetle ┆ 5   ┆ 148.4131591025766  │
# └────────┴────────┴─────┴────────────────────┘
